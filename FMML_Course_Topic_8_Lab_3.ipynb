# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmikalyani348/FMML--Lab/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 05:14:00--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   210MB/s    in 0.3s
#
# 2024-03-31 05:14:01 (210 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5758    1206.4560v1  Probabilistic principal component analysis (PP...    cs
# 654    1712.09687v1  The current state-of-the-art in many natural l...    cs
# 3872   1512.06293v3  Deep convolutional neural networks have led to...    cs
# 34596  1705.07318v1  In this project, a rather complete proof-theor...    cs
# 22099   1411.2540v2  This paper considers statistical estimation pr...  stat
# ...             ...                                                ...   ...
# 383    1707.08167v2  With the development of neural networks based ...  stat
# 4099    1112.2095v1  To study the preference of infants for conting...    cs
# 22540  1611.00798v1  Many machine learning algorithms require preci...  stat
# 4445   1711.08364v1  Hash codes are efficient data representations ...    cs
# 22022   1311.6359v3  Given data sampled from a number of variables,...  stat
#
#                                                    title  year  \
# 5758   Residual Component Analysis: Generalising PCA ...  2012
# 654    Combining Representation Learning with Logic f...  2017
# 3872   A Mathematical Theory of Deep Convolutional Ne...  2015
# 34596  Formalized Lambek Calculus in Higher Order Log...  2017
# 22099  Parameter estimation in spherical symmetry groups  2014
# ...                                                  ...   ...
# 383                On The Robustness of a Neural Network  2017
# 4099   Real-time face swapping as a tool for understa...  2011
# 22540         Cross-validation based Nonlinear Shrinkage  2016
# 4445   ForestHash: Semantic Hashing With Shallow Rand...  2017
# 22022  Score-based Causal Learning in Additive Noise ...  2013
#
#                                                 keywords
# 5758   [probabilistic, principal, component, dimensio...
# 654    [processing, automated, knowledge, completion,...
# 3872   [convolutional, breakthrough, practical, class...
# 34596  [theoretical, formalization, associative, arbi...
# 22099  [considers, statistical, estimation, probabili...
# ...                                                  ...
# 383    [development, applications, textitblack, under...
# 4099   [preference, contingency, movements, familiari...
# 22540  [algorithms, estimates, covariance, covariance...
# 4445   [efficient, representations, introduce, convol...
# 22022  [variables, interested, underlying, relationsh...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5758     [probabilistic, principal, component, dimensio...
# 654      [processing, automated, knowledge, completion,...
# 3872     [convolutional, breakthrough, practical, class...
# 34596    [theoretical, formalization, associative, arbi...
# 22099    [considers, statistical, estimation, probabili...
#                                ...
# 18162    [interpret, sequences, automatically, recognit...
# 13307    [adaptation, covariance, adaptation, evolution...
# 6686     [distribution, regression, attracted, supervis...
# 32683    [implementation, parallelism, performance, com...
# 2887     [riemannian, orbifolds, motivated, algorithms,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8740 words.
# Out of those 4594 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8186297a-a1b0-4a19-b4de-a5082aa0cfd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8186297a-a1b0-4a19-b4de-a5082aa0cfd7")) {                    Plotly.newPlot(                        "8186297a-a1b0-4a19-b4de-a5082aa0cfd7",                        [{"x":["signaling","spherical","factorises","framework","independent","explained","generalising","expression","covariates","eigenvalue","likelihood","covariance","dimensional","inference","illustrate","component","algorithms","representation","correlations","partially","conditional","principal","generalised","probabilistic","situation","including","decompose","dependencies","components","distributed","investigates","different","combining","improving","annotations","generalize","processing","combinations","annotators","assumptions","optimization","automated","generalization","preprocessing","annotated","completion","specifying","representations","knowledge","extractor","complements","linearities","linearity","transforms","technical","sensitivity","rectified","transform","encompasses","deformation","increasing","stability","breakthrough","functions","considered","progressively","shearlets","mathematical","initiated","scattering","classifier","translation","extraction","continuous","classification","hyperbolic","establish","averaging","resulting","developing","applications","invariance","specifically","emulating","captioning","trainable","practical","corresponding","invariant","lipschitz","convolutional","operators","customized","extensions","associative","deduction","arbitrary","formalized","properties","multimodal","languages","improvements","sensitive","implemented","theoretical","formalization","preliminary","estimated","simulations","advantages","estimation","microscopy","orientation","parameterized","parameters","parameter","respectively","extension","distribution","concentration","illustrated","experiments","specialized","topological","considers","symmetric","distributions","restricted","expectation","algorithm","spherically","probability","statistical","estimator","associated","maximization","challenging","challenge","performance","experimentally","benchmark","information","extracted","incremental","techniques","successful","segmentation","operating","outperforms","variations","background","effective","incorporate","detection","weighting","appearance","conditions","especially","enterprise","analytics","comprises","application","integrate","automation","construction","technological","execution","challenges","manufacturing","predictive","generation","heterogeneous","motivations","operations","elaborate","management","therefore","integration","influence","computing","discussion","pedestrian","discusses","artificial","artificially","limitations","intelligent","intelligence","decoupled","supervised","effectively","calculating","generalizations","covariances","flexibility","uncertainty","processes","layerwise","computational","multilayer"],"y":[1,9,1,562,127,20,3,42,3,7,63,23,185,210,72,99,591,368,38,41,75,38,8,153,30,259,16,58,108,99,26,719,100,98,68,43,277,35,10,65,325,98,115,30,77,29,14,231,364,7,6,1,7,15,42,30,9,67,4,20,100,34,2,194,128,10,2,71,5,5,134,124,145,105,502,4,61,20,156,58,440,31,155,3,24,18,143,130,65,10,377,40,10,30,9,5,96,12,198,35,112,114,44,103,158,7,49,57,47,69,179,11,23,20,237,115,72,80,214,4,15,584,16,32,33,21,122,46,23,835,1,143,162,22,109,26,283,166,875,34,216,692,111,28,354,100,217,20,269,78,71,239,58,339,18,86,155,124,3,14,15,251,36,10,72,3,29,112,9,50,156,29,3,61,11,59,138,63,48,136,11,12,23,145,9,59,56,99,3,215,101,8,6,1,34,80,102,2,296,15],"type":"bar"},{"x":["signaling","spherical","factorises","framework","independent","explained","generalising" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4594,), (4594, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Loopy</span> <span style=''>Belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <span style=''>in</span> <span style=''>Bayesian</span> <span style=''>Networks</span> <span style=''>origin</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>possibilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspectives</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636365);'>synthesis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>work</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performed</span> <span style=''>on</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3080724876441515);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>the</span> <span style=''>Pearls</span> <span style=''>belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>(BP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>without</span> <span style=''>loops</span> <span style=''>(ie</span> <span style=''>polytree)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>Loopy</span> <span style=''>belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>(LBP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>(inspired</span> <span style=''>from</span> <span style=''>the</span> <span style=''>BP)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>networks</span> <span style='background-color:rgba(0, 255, 0, 0.39534883720930236);'>containing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>undirected</span> <span style=''>cycles</span> <span style=''>It</span> <span style=''>is</span> <span style=''>known</span> <span style=''>that</span> <span style=''>the</span> <span style=''>BP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>loops</span> <span style=''>gives</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>incorrect</span> <span style='background-color:rgba(255, 0, 0, 0.4923076923076923);'>numerical</span> <span style=''>results</span> <span style=''>ie</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>incorrect</span> <span style='background-color:rgba(255, 0, 0, 0.645320197044335);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style=''>Murphy</span> <span style=''>and</span> <span style=''>al</span> <span style=''>7</span> <span style=''>find</span> <span style=''>that</span> <span style=''>the</span> <span style=''>LBP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.30303030303030304);'>converges</span> <span style=''>on</span> <span style=''>several</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>when</span> <span style=''>this</span> <span style=''>occurs</span> <span style=''>LBP</span> <span style=''>gives</span> <span style=''>a</span> <span style=''>good</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.6453201970 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Adaptive</span> <span style=''>and</span> <span style=''>Optimal</span> <span style=''>Online</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>on</span> <span style=''>L1</span> <span style=''>balls</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>online</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>The</span> <span style=''>goal</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>is</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecaster</span> <span style=''>to</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>which</span> <span style=''>are</span> <span style=''>after</span> <span style=''>T</span> <span style=''>time</span> <span style=''>rounds</span> <span style=''>almost</span> <span style=''>as</span> <span style=''>good</span> <span style=''>as</span> <span style=''>the</span> <span style=''>ones</span> <span style=''>output</span> <span style=''>by</span> <span style=''>the</span> <span style=''>best</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictor</span> <span style=''>in</span> <span style=''>a</span> <span style=''>given</span> <span style=''>L1</span> <span style=''>ball</span> <span style=''>in</span> <span style=''>Rd</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>both</span> <span style=''>the</span> <span style=''>cases</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>d</span> <span style=''>is</span> <span style=''>small</span> <span style=''>and</span> <span style=''>large</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>the</span> <span style=''>time</span> <span style=''>horizon</span> <span style=''>T</span> <span style=''>We</span> <span style=''>first</span> <span style=''>present</span> <span style=''>regret</span> <span style=''>bounds</span> <span style=''>with</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>on</span> <span style=''>the</span> <span style=''>sizes</span> <span style=''>U</span> <span style=''>X</span> <span style=''>and</span> <span style=''>Y</span> <span style=''>of</span> <span style=''>the</span> <span style=''>L1</span> <span style=''>ball</span> <span style=''>the</span> <span style=''>input</span> <span style=''>data</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>The</span> <span style=''>minimax</span> <span style=''>regret</span> <span style=''>is</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>exhibit</span> <span style=''>a</span> <span style=''>regime</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transition</span> <span style=''>around</span> <span style=''>the</span> <span style=''>point</span> <span style=''>d</span> <span style=''>sqrt(T)</span> <span style=''>U</span> <span style=''>X</span> <span style=''>(2</span> <span style=''>Y)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Furthermore</span> <span style=''>we</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Note</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Equivalence</span> <span style=''>Between</span> <span style='background-color:rgba(0, 255, 0, 0.35885167464114814);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>Time</span> <span style=''>Series</span> <span style=''>Models</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5517241379310345);'>Variational</span> <span style=''>Bayesian</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>observe</span> <span style=''>that</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>log</span> <span style='background-color:rgba(255, 0, 0, 0.48571428571428577);'>likelihood</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.35885167464114814);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Network</span> <span style=''>(RNN)</span> <span style=''>model</span> <span style=''>of</span> <span style=''>time</span> <span style=''>series</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.5517241379310345);'>variational</span> <span style=''>Bayesian</span> <span style=''>training</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>given</span> <span style=''>the</span> <span style=''>proper</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3080724876441515);'>inference</span> <span style=''>models</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>may</span> <span style=''>motivate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>both</span> <span style=''>RNNs</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5517241379310345);'>variational</span> <span style=''>Bayesian</span> <span style=''>models</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>one</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extension</span> <span style=''>where</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particles</span> <span style=''>are</span> <span style=''>used</span> <span style=''>for</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>state</span> <span style=''>of</span> <span style=''>an</span> <span style=''>RNN</span> <span style=''>allowing</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3604436229205175);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multimodality</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Multi</span> <span style=''>Scheme</span> <span style=''>Ensemble</span> <span style=''>Using</span> <span style=''>Coopetitive</span> <span style=''>Soft</span> <span style=''>Gating</span> <span style=''>With</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Application</span> <span style=''>to</span> <span style=''>Power</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Renewable</span> <span style=''>Energy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generation</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>ensemble</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>with</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>scheme</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>weighting</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>called</span> <span style=''>coopetitive</span> <span style=''>soft</span> <span style=''>gating</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>combines</span> <span style=''>both</span> <span style=''>ensemble</span> <span style=''>member</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competition</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cooperation</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>the</span> <span style=''>overall</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ensemble</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>ideas</span> <span style=''>of</span> <span style=''>multiple</span> <span style=''>ensemble</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>paradigms</span> <span style=''>(power</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>model</span> <span style=''>ensemble</span> <span style=''>weather</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>model</span> <span style=''>ensemble</span> <span style=''>and</span> <span style=''>lagged</span> <span style=''>ensemble)</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>is</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>in</span> <span style=''>a</span> <span style=''>flexible</span> <span style=''>manner</span> <span style=''>on</span> <span style=''>single</span> <span style=''>and</span> <span style=''>multiple</span> <span style=''>weather</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasting</span> <span style=''>models</span> <span style=''>and</span> <span style=''>for</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>lead</span> <span style=''>times</span> <span style=''>We</span> <span style=''>compare</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>te ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.12881476224272534)
# 	representation (0.13058907026259758)
# 	challenging (0.10042583392476934)
# 	knowledge (0.12916962384669978)
# 	segmentation (0.07700496806245564)
# 	detection (0.12029808374733854)
# 	different (0.25514549325762953)
# 	information (0.24556422995031937)
# 	convolutional (0.13378282469836764)
# 	recognition (0.1391057487579844)
#
# Some Statistics words are:
# 	stochastic (0.1311806256306761)
# 	variables (0.13521695257315844)
# 	theoretical (0.14883955600403634)
# 	algorithm (0.393037336024218)
# 	distribution (0.17961654894046417)
# 	statistical (0.16599394550958627)
# 	estimation (0.17709384460141273)
# 	dimensional (0.18970736629667004)
# 	inference (0.20030272452068618)
# 	regression (0.17759838546922302)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8bb199a0-7dcf-428a-b1d0-e9b888505a77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8bb199a0-7dcf-428a-b1d0-e9b888505a77")) {                    Plotly.newPlot(                        "8bb199a0-7dcf-428a-b1d0-e9b888505a77",                        [{"x":["signaling","spherical","factorises","framework","independent","explained","generalising","expression","covariates","eigenvalue","likelihood","covariance","dimensional","inference","illustrate","component","algorithms","representation","correlations","partially","conditional","principal","generalised","probabilistic","situation","including","decompose","dependencies","components","distributed","investigates","different","combining","improving","annotations","generalize","processing","combinations","annotators","assumptions","optimization","automated","generalization","preprocessing","annotated","completion","specifying","representations","knowledge","extractor","complements","linearities","linearity","transforms","technical","sensitivity","rectified","transform","encompasses","deformation","increasing","stability","breakthrough","functions","considered","progressively","shearlets","mathematical","initiated","scattering","classifier","translation","extraction","continuous","classification","hyperbolic","establish","averaging","resulting","developing","applications","invariance","specifically","emulating","captioning","trainable","practical","corresponding","invariant","lipschitz","convolutional","operators","customized","extensions","associative","deduction","arbitrary","formalized","properties","multimodal","languages","improvements","sensitive","implemented","theoretical","formalization","preliminary","estimated","simulations","advantages","estimation","microscopy","orientation","parameterized","parameters","parameter","respectively","extension","distribution","concentration","illustrated","experiments","specialized","topological","considers","symmetric","distributions","restricted","expectation","algorithm","spherically","probability","statistical","estimator","associated","maximization","challenging","challenge","performance","experimentally","benchmark","information","extracted","incremental","techniques","successful","segmentation","operating","outperforms","variations","background","effective","incorporate","detection","weighting","appearance","conditions","especially","enterprise","analytics","comprises","application","integrate","automation","construction","technological","execution","challenges","manufacturing","predictive","generation","heterogeneous","motivations","operations","elaborate","management","therefore","integration","influence","computing","discussion","pedestrian","discusses","artificial","artificially","limitations","intelligent","intelligence","decoupled","supervised","effectively","calculating","generalizations","covariances","flexibility","uncertainty","processes","layerwise","computational","multilayer","estimates","hierarchical","approximated","calibrated","regression","simulated","reinforcement","relevance","important","precisely","capability","environment","encouraging","learnable","parametric","environments","transitions","approximate","attention","stationary","mechanism","recurrent","observable","observation","unbounded","markovian","sequential","composite","maximizing","perception","assessment","registered","informative","biometrics","forecasting","redundancy","evaluation","constraint","empirically","generalized","vocabulary","initialization","converges","retrieval","selection","correlation","minimization","convergence","canonical","generated","majorization","demonstrated","constraining","approximation","programming","discriminant","c ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	sparsistency
# 	waveforms
# 	seasonality
# 	inexactly
# 	aleatoric
# 	unmeasured
# 	invertible
# 	undersampling
# 	smoothers
# 	multitype
# 	stochasticity
# 	elsewhere
# 	confounders
# 	interpolate
# 	rightarrow
# 	actigraphy
# 	cigarette
# 	blockmodel
# 	lightspeed
# 	regressions
# Some words which never appear in Statistics papers:
# 	shearlets
# 	initiated
# 	deduction
# 	pedestrian
# 	workstation
# 	multiobjective
# 	recognizes
# 	argumentation
# 	communitys
# 	indifference
# 	denominator
# 	authorship
# 	punctuation
# 	compensation
# 	autoepistemic
# 	propositional
# 	stylistic
# 	synchronize
# 	coexistence
# 	multilayered

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.051199121254653e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
